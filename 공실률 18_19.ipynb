# %%
import pandas as pd
import openpyxl
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# 한글 패치
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline 
get_ipython().run_line_magic("matplotlib", "inline")

# %%
df_18 = pd.read_excel('18_공실률.xls')

# %%
df_19 = pd.read_excel('19_공실률.xls')

# %%
df_18 = df_18[['하위상권', '공실률']]

# %%
df_19 = df_19[['하위상권', '공실률']]

# %%
df_18 = df_18.drop(df_18.index[0])

# %%
df_19 = df_19.drop(df_19.index[0])
df_19
# Out:
#     하위상권   공실률
# 1     서울   9.1
# 2     소계  10.4
# 3    광화문   7.4
# 4    동대문  10.3
# 5     명동   9.2
# 6    남대문   7.8
# 7     시청  10.4
# 8    을지로  14.1
# 9     종로  10.6
# 10   충무로  19.1
# 11    소계   7.4
# 12  강남대로   9.5
# 13   논현역   4.7
# 14  도산대로  11.1
# 15    서초   8.2
# 16   신사역   6.3
# 17  테헤란로   6.9
# 18    소계  10.5
# 19   공덕역     7
# 20   여의도    11
# 21   영등포  12.9
# 22    소계  11.5
# 23    목동  13.2
# 24    사당     5
# 25    용산   6.8
# 26    잠실  12.2
# 27   장안동  12.8
# 28    천호  14.8
# 29  홍대합정   4.9
# 30    화곡  19.9

# %%
coB = pd.merge(df_18, df_19, on="하위상권")
coB
# Out:
#     하위상권 공실률_x 공실률_y
# 0     서울  11.4   9.1
# 1     소계  14.5  10.4
# 2     소계  14.5   7.4
# 3     소계  14.5  10.5
# 4     소계  14.5  11.5
# 5     소계   8.4  10.4
# 6     소계   8.4   7.4
# 7     소계   8.4  10.5
# 8     소계   8.4  11.5
# 9     소계  11.3  10.4
# 10    소계  11.3   7.4
# 11    소계  11.3  10.5
# 12    소계  11.3  11.5
# 13    소계    14  10.4
# 14    소계    14   7.4
# 15    소계    14  10.5
# 16    소계    14  11.5
# 17   광화문   7.6   7.4
# 18   동대문   8.4  10.3
# 19    명동   9.5   9.2
# 20    종로    19  10.6
# 21   충무로  20.9  19.1
# 22  강남대로  18.5   9.5
# 23   논현역   2.6   4.7
# 24  도산대로   7.9  11.1
# 25    서초  10.6   8.2
# 26  테헤란로   6.5   6.9
# 27   공덕역   5.8     7
# 28   여의도  12.7    11
# 29   영등포  11.8  12.9
# 30    목동  20.9  13.2
# 31    사당   4.8     5
# 32    용산  17.5   6.8
# 33    잠실  12.2  12.2
# 34   장안동  12.4  12.8
# 35    천호  12.6  14.8
# 36  홍대합정   4.1   4.9
# 37    화곡  20.8  19.9

# %%
# 서울 지역만 남기고 날림
coB = coB.drop(coB.index[:17])

# %%
coB
# Out:
#     하위상권 공실률_x 공실률_y
# 17   광화문   7.6   7.4
# 18   동대문   8.4  10.3
# 19    명동   9.5   9.2
# 20    종로    19  10.6
# 21   충무로  20.9  19.1
# 22  강남대로  18.5   9.5
# 23   논현역   2.6   4.7
# 24  도산대로   7.9  11.1
# 25    서초  10.6   8.2
# 26  테헤란로   6.5   6.9
# 27   공덕역   5.8     7
# 28   여의도  12.7    11
# 29   영등포  11.8  12.9
# 30    목동  20.9  13.2
# 31    사당   4.8     5
# 32    용산  17.5   6.8
# 33    잠실  12.2  12.2
# 34   장안동  12.4  12.8
# 35    천호  12.6  14.8
# 36  홍대합정   4.1   4.9
# 37    화곡  20.8  19.9

# %%
coB['평균'] = coB.iloc[:, 1:3].mean(axis=1)

# %%
coB = coB.reset_index()

# %%
coB = coB.drop('index', 1)
# Out:
# C:\Users\82103\AppData\Local\Temp/ipykernel_5552/528844221.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   coB = coB.drop('index', 1)

# %%
# ...없애기
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
plt.figure(figsize=(15,10))

splot = sns.barplot(data=coB, x='하위상권', y='평균')


plt.show()
sfig = splot.get_figure()
sfig.savefig('2018-19_empty.png')

# %%
coB.to_csv('2018-19 공실률.csv')
