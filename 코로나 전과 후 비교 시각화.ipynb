# %%
import pandas as pd
import openpyxl
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# 한글 패치
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline 
get_ipython().run_line_magic("matplotlib", "inline")

# %%
coB = pd.read_csv('2018-19 공실률.csv')
coB
# Out:
#     Unnamed: 0  하위상권  공실률_x  공실률_y     평균
# 0            0   광화문    7.6    7.4   7.50
# 1            1   동대문    8.4   10.3   9.35
# 2            2    명동    9.5    9.2   9.35
# 3            3    종로   19.0   10.6  14.80
# 4            4   충무로   20.9   19.1  20.00
# 5            5  강남대로   18.5    9.5  14.00
# 6            6   논현역    2.6    4.7   3.65
# 7            7  도산대로    7.9   11.1   9.50
# 8            8    서초   10.6    8.2   9.40
# 9            9  테헤란로    6.5    6.9   6.70
# 10          10   공덕역    5.8    7.0   6.40
# 11          11   여의도   12.7   11.0  11.85
# 12          12   영등포   11.8   12.9  12.35
# 13          13    목동   20.9   13.2  17.05
# 14          14    사당    4.8    5.0   4.90
# 15          15    용산   17.5    6.8  12.15
# 16          16    잠실   12.2   12.2  12.20
# 17          17   장안동   12.4   12.8  12.60
# 18          18    천호   12.6   14.8  13.70
# 19          19  홍대합정    4.1    4.9   4.50
# 20          20    화곡   20.8   19.9  20.35

# %%
coB = coB.drop('Unnamed: 0', 1)
# Out:
# C:\Users\82103\AppData\Local\Temp/ipykernel_26772/3080849700.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   coB = coB.drop('Unnamed: 0', 1)

# %%
coA = pd.read_csv('2020-21 공실률.csv')

# %%
coA = coA.drop('Unnamed: 0', 1)
# Out:
# C:\Users\82103\AppData\Local\Temp/ipykernel_26772/4095951884.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   coA = coA.drop('Unnamed: 0', 1)

# %%
coA
# Out:
#     하위상권  공실률_x  공실률_y     평균
# 0    광화문    5.8    5.7   5.75
# 1    남대문   10.3   11.3  10.80
# 2    동대문   17.7   12.8  15.25
# 3     명동   12.6   14.7  13.65
# 4     시청    8.9   10.5   9.70
# 5    을지로   11.9   11.4  11.65
# 6     종로   15.0   13.0  14.00
# 7    충무로   18.3   14.9  16.60
# 8   강남대로    6.4    8.3   7.35
# 9    논현역    2.2    9.0   5.60
# 10  도산대로   10.9    5.5   8.20
# 11   신사역    7.9    6.6   7.25
# 12  테헤란로    7.2    6.2   6.70
# 13   공덕역    7.0    7.0   7.00
# 14   여의도    8.8    9.1   8.95
# 15    목동   11.3    1.7   6.50
# 16    사당    3.2    7.2   5.20
# 17   장안동   14.2    3.2   8.70
# 18    천호    8.7    7.1   7.90
# 19  홍대합정    8.6    6.8   7.70
# 20    화곡   12.2   16.3  14.25

# %%
# 2개의 데이터로 그리는 bar 그래프 실패..

# plt.figure(figsize=(15, 10))

# # plt.bar(data=coB, x='하위상권', height='평균', color='r')
# # plt.bar(data=coA, x='하위상권', height='평균', color='b')
# sns.barplot(data=coB, x='하위상권', y='평균', color='r', label='코로나 전 공실률 평균')
# sns.barplot(data=coA, x='하위상권', y='평균', color='b', label='코로나 후 공실률 평균')
# plt.show()

# %%
# 선 그래프
plt.figure(figsize=(15, 10))

sns.lineplot(data=co, x='하위상권', y='평균', label='코로나 전 공실률 평균')
sns.lineplot(data=coA, x='하위상권', y='평균', color='r', label='코로나 후 공실률 평균')

plt.show()
sfig = splot.get_figure()
sfig.savefig('2020-21_empty.png')
# Out:
# <AxesSubplot:xlabel='하위상권', ylabel='평균'>
# <AxesSubplot:xlabel='하위상권', ylabel='평균'>

# %%
co = pd.merge(coA, coB, on='하위상권')
co
# Out:
#     하위상권  공실률_x_x  공실률_y_x   평균_x  공실률_x_y  공실률_y_y   평균_y
# 0    광화문      5.8      5.7   5.75      7.6      7.4   7.50
# 1    동대문     17.7     12.8  15.25      8.4     10.3   9.35
# 2     명동     12.6     14.7  13.65      9.5      9.2   9.35
# 3     종로     15.0     13.0  14.00     19.0     10.6  14.80
# 4    충무로     18.3     14.9  16.60     20.9     19.1  20.00
# 5   강남대로      6.4      8.3   7.35     18.5      9.5  14.00
# 6    논현역      2.2      9.0   5.60      2.6      4.7   3.65
# 7   도산대로     10.9      5.5   8.20      7.9     11.1   9.50
# 8   테헤란로      7.2      6.2   6.70      6.5      6.9   6.70
# 9    공덕역      7.0      7.0   7.00      5.8      7.0   6.40
# 10   여의도      8.8      9.1   8.95     12.7     11.0  11.85
# 11    목동     11.3      1.7   6.50     20.9     13.2  17.05
# 12    사당      3.2      7.2   5.20      4.8      5.0   4.90
# 13   장안동     14.2      3.2   8.70     12.4     12.8  12.60
# 14    천호      8.7      7.1   7.90     12.6     14.8  13.70
# ...

# %%
# plt.figure(figsize=(15, 10))
# g = sns.catplot(
#     data=co, kind="bar",
#     x="하위상권", y="평균_x", hue="평균_y",
#     ci="sd", palette="dark", alpha=1, height=6
# )
# g.despine(left=True)
# g.legend.set_title("")
# Out:
#   File "C:\Users\82103\AppData\Local\Temp/ipykernel_26772/2318158853.py", line 2
#     g = sns.catplot(
#
# ^
# SyntaxError: keyword argument repeated: y

# %%
co.to_csv('2018~2021 공실률 평균.csv')
