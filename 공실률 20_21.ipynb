# %%
import pandas as pd
import openpyxl
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# 한글 패치
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline 
get_ipython().run_line_magic("matplotlib", "inline")

# %%
df_20 = pd.read_excel('20_공실률.xls')
df_20
# Out:
#       기간     광역상권  하위상권   임대료   공실률 수익률 정보 수익률 정보.1 수익률 정보.2
# 0     기간     광역상권  하위상권   임대료   공실률  투자수익률    소득수익률    자본수익률
# 1   2020       서울    서울  22.4   8.6   6.86     4.17     2.61
# 2   2020     도심지역    소계    28  10.7   6.33     4.28     1.99
# 3   2020     도심지역   광화문  32.8   5.8    6.2     4.81     1.34
# 4   2020     도심지역   남대문  32.3  10.3   7.71     5.52     2.11
# 5   2020     도심지역   동대문  15.1  17.7   5.59     3.42     2.12
# 6   2020     도심지역    명동  22.2  12.6   4.82     3.36     1.42
# 7   2020     도심지역    시청  23.5   8.9   7.03     3.97     2.97
# 8   2020     도심지역   을지로  32.8  11.9   6.19     3.97     2.16
# 9   2020     도심지역    종로    22    15   7.32     4.48     2.74
# 10  2020     도심지역   충무로    14  18.3   4.26     3.37     0.86
# 11  2020     강남지역    소계  23.3   7.2   7.32      3.7     3.52
# 12  2020     강남지역  강남대로  25.6   6.4   6.38     3.65     2.66
# 13  2020     강남지역   논현역    22   2.2   6.48     5.03      1.4
# 14  2020     강남지역  도산대로  17.7  10.9   4.52     3.44     1.06
# 15  2020     강남지역    서초  18.9   7.6   6.63     3.11     3.44
# 16  2020     강남지역   신사역  20.5   7.9   6.16     2.58     3.52
# 17  2020     강남지역  테헤란로  23.9   7.2   7.93     3.88     3.94
# 18  2020  여의도마포지역    소계  18.1   8.7   7.55     4.72     2.73
# 19  2020  여의도마포지역   공덕역  15.7     7   6.63     4.28     2.28
# 20  2020  여의도마포지역   여의도  19.6   8.8   7.81     4.89     2.82
# 21  2020  여의도마포지역   영등포  13.5  10.7   7.46      4.4     2.96
# 22  2020     기타지역    소계  13.6  10.1   6.39     3.83     2.49
# 23  2020     기타지역    목동  12.5  11.3   6.52     4.92     1.54
# 24  2020     기타지역    사당  20.3   3.2   4.99     4.42     0.55
# 25  2020     기타지역    용산  14.8  13.5   6.89     3.39     3.42
# 26  2020     기타지역    잠실    16    10   6.67     3.13     3.45
# 27  2020     기타지역   장안동  10.3  14.2   5.21     2.58     2.58
# 28  2020     기타지역    천호    12   8.7   7.77     3.69     3.98
# 29  2020     기타지역  홍대합정  17.3   8.6    5.6     3.71     1.84
# 30  2020     기타지역    화곡   8.1  12.2   4.95     2.55     2.36

# %%
df_21 = pd.read_excel('21_공실률.xls')

# %%
df_20 = df_20[['하위상권', '공실률']]

# %%
df_21 = df_21[['하위상권', '공실률']]

# %%
df_21
# Out:
#      하위상권   공실률
# 0    하위상권   공실률
# 1      서울   7.8
# 2      소계  10.8
# 3     광화문   5.7
# 4     남대문  11.3
# 5     동대문  12.8
# 6      명동  14.7
# 7      시청  10.5
# 8     을지로  11.4
# 9      종로    13
# 10    충무로  14.9
# 11     소계   6.6
# 12   강남대로   8.3
# 13    논현역     9
# 14    교대역   8.7
# 15  남부터미널   1.1
# 16   도산대로   5.5
# 17    신사역   6.6
# 18   테헤란로   6.2
# 19     소계   8.6
# 20    공덕역     7
# 21    당산역   3.9
# 22    여의도   9.1
# 23   영등포역  11.5
# 24     소계   6.9
# 25     목동   1.7
# 26     사당   7.2
# 27   숙명여대  13.2
# 28    용산역  16.5
# 29   잠실송파   9.3
# 30  잠실새내역   4.1
# 31    장안동   3.2
# 32     천호   7.1
# 33   홍대합정   6.8
# 34     화곡  16.3

# %%
coA = pd.merge(df_20, df_21, on='하위상권')
coA
# Out:
#     하위상권 공실률_x 공실률_y
# 0   하위상권   공실률   공실률
# 1     서울   8.6   7.8
# 2     소계  10.7  10.8
# 3     소계  10.7   6.6
# 4     소계  10.7   8.6
# 5     소계  10.7   6.9
# 6     소계   7.2  10.8
# 7     소계   7.2   6.6
# 8     소계   7.2   8.6
# 9     소계   7.2   6.9
# 10    소계   8.7  10.8
# 11    소계   8.7   6.6
# 12    소계   8.7   8.6
# 13    소계   8.7   6.9
# 14    소계  10.1  10.8
# 15    소계  10.1   6.6
# 16    소계  10.1   8.6
# 17    소계  10.1   6.9
# 18   광화문   5.8   5.7
# 19   남대문  10.3  11.3
# 20   동대문  17.7  12.8
# 21    명동  12.6  14.7
# 22    시청   8.9  10.5
# 23   을지로  11.9  11.4
# 24    종로    15    13
# 25   충무로  18.3  14.9
# 26  강남대로   6.4   8.3
# 27   논현역   2.2     9
# 28  도산대로  10.9   5.5
# 29   신사역   7.9   6.6
# 30  테헤란로   7.2   6.2
# 31   공덕역     7     7
# 32   여의도   8.8   9.1
# 33    목동  11.3   1.7
# 34    사당   3.2   7.2
# 35   장안동  14.2   3.2
# 36    천호   8.7   7.1
# 37  홍대합정   8.6   6.8
# 38    화곡  12.2  16.3

# %%
# 소계 다 짤라 버리기
coA = coA.drop(coA.index[:18])

# %%
coA = coA.reset_index()
coA
# Out:
#     index  하위상권 공실률_x 공실률_y
# 0      18   광화문   5.8   5.7
# 1      19   남대문  10.3  11.3
# 2      20   동대문  17.7  12.8
# 3      21    명동  12.6  14.7
# 4      22    시청   8.9  10.5
# 5      23   을지로  11.9  11.4
# 6      24    종로    15    13
# 7      25   충무로  18.3  14.9
# 8      26  강남대로   6.4   8.3
# 9      27   논현역   2.2     9
# 10     28  도산대로  10.9   5.5
# 11     29   신사역   7.9   6.6
# 12     30  테헤란로   7.2   6.2
# 13     31   공덕역     7     7
# 14     32   여의도   8.8   9.1
# 15     33    목동  11.3   1.7
# 16     34    사당   3.2   7.2
# 17     35   장안동  14.2   3.2
# 18     36    천호   8.7   7.1
# 19     37  홍대합정   8.6   6.8
# 20     38    화곡  12.2  16.3

# %%
coA = coA.drop('index',1)
coA
# Out:
# C:\Users\82103\AppData\Local\Temp/ipykernel_15368/2991774762.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   coA = coA.drop('index',1)
#     하위상권 공실률_x 공실률_y
# 0    광화문   5.8   5.7
# 1    남대문  10.3  11.3
# 2    동대문  17.7  12.8
# 3     명동  12.6  14.7
# 4     시청   8.9  10.5
# 5    을지로  11.9  11.4
# 6     종로    15    13
# 7    충무로  18.3  14.9
# 8   강남대로   6.4   8.3
# 9    논현역   2.2     9
# 10  도산대로  10.9   5.5
# 11   신사역   7.9   6.6
# 12  테헤란로   7.2   6.2
# 13   공덕역     7     7
# 14   여의도   8.8   9.1
# 15    목동  11.3   1.7
# 16    사당   3.2   7.2
# 17   장안동  14.2   3.2
# 18    천호   8.7   7.1
# 19  홍대합정   8.6   6.8
# 20    화곡  12.2  16.3

# %%
coA['평균'] = coA.iloc[:, 1:].mean(axis=1)
coA
# Out:
#     하위상권 공실률_x 공실률_y     평균
# 0    광화문   5.8   5.7   5.75
# 1    남대문  10.3  11.3  10.80
# 2    동대문  17.7  12.8  15.25
# 3     명동  12.6  14.7  13.65
# 4     시청   8.9  10.5   9.70
# 5    을지로  11.9  11.4  11.65
# 6     종로    15    13  14.00
# 7    충무로  18.3  14.9  16.60
# 8   강남대로   6.4   8.3   7.35
# 9    논현역   2.2     9   5.60
# 10  도산대로  10.9   5.5   8.20
# 11   신사역   7.9   6.6   7.25
# 12  테헤란로   7.2   6.2   6.70
# 13   공덕역     7     7   7.00
# 14   여의도   8.8   9.1   8.95
# 15    목동  11.3   1.7   6.50
# 16    사당   3.2   7.2   5.20
# 17   장안동  14.2   3.2   8.70
# 18    천호   8.7   7.1   7.90
# 19  홍대합정   8.6   6.8   7.70
# 20    화곡  12.2  16.3  14.25

# %%
# ...없애기
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
plt.figure(figsize=(15,10))
splot = sns.barplot(data=coA, x='하위상권', y='평균')
plt.show()
sfig = splot.get_figure()
sfig.savefig('2020-21_empty.png')
